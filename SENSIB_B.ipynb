# %%
import pickle
from RE import RGenerator
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import statistics

precision = []
recall = []
f1_score = []

for r in range(30, 91, 10):
    with open(f"/home/stagiaire/D/R/metrics/{r}.pkl", "rb") as f:
        metrics = pickle.load(f) 
    new_metrics = []
    for l in metrics:
        new_metrics.extend(l)  
    report = RGenerator(new_metrics).report()
    precision_mean , _ = report[0]
    precision.append(precision_mean)
    recall_mean , _ = report[1]
    recall.append(recall_mean)
    f1_score_mean , _ = report[2]
    f1_score.append(f1_score_mean)
# Out:
# Precision (mean, stdev): 75%, 2%
# Recall (mean, stdev): 76%, 3%
# F1-score (mean, stdev): 76%, 2%
# IoU (mean, stdev): 61%, 2%
#
# [[330. 112.]
#  [106. 336.]]
#
# [[ 9. 11.]
#  [14. 13.]]
#
# Precision (mean, stdev): 77%, 3%
# Recall (mean, stdev): 78%, 3%
# F1-score (mean, stdev): 77%, 2%
# IoU (mean, stdev): 63%, 2%
#
# [[278.  87.]
#  [ 80. 284.]]
#
# [[12. 14.]
#  [11. 11.]]
#
# Precision (mean, stdev): 79%, 3%
# Recall (mean, stdev): 79%, 4%
# F1-score (mean, stdev): 79%, 2%
# IoU (mean, stdev): 66%, 2%
#
# [[235.  61.]
#  [ 61. 235.]]
#
# [[10. 11.]
#  [12.  9.]]
#
# Precision (mean, stdev): 81%, 2%
# Recall (mean, stdev): 82%, 4%
# F1-score (mean, stdev): 81%, 2%
# IoU (mean, stdev): 68%, 3%
#
# [[191.  46.]
#  [ 43. 194.]]
#
# [[ 8.  7.]
#  [10. 10.]]
#
# Precision (mean, stdev): 82%, 4%
# Recall (mean, stdev): 82%, 5%
# F1-score (mean, stdev): 82%, 3%
# IoU (mean, stdev): 69%, 4%
#
# [[151.  34.]
#  [ 33. 152.]]
#
# [[ 7.  9.]
#  [10. 10.]]
#
# Precision (mean, stdev): 83%, 3%
# Recall (mean, stdev): 84%, 4%
# F1-score (mean, stdev): 84%, 2%
# IoU (mean, stdev): 72%, 3%
#
# [[110.  22.]
#  [ 21. 112.]]
#
# [[7. 4.]
#  [6. 7.]]
#
# Precision (mean, stdev): 84%, 5%
# Recall (mean, stdev): 84%, 4%
# F1-score (mean, stdev): 84%, 3%
# IoU (mean, stdev): 72%, 4%
#
# [[77. 15.]
#  [15. 77.]]
#
# [[5. 5.]
#  [4. 6.]]

# %%
plt.plot(range(30, 91, 10), precision, marker="o", linestyle="-", label = "Precision")
plt.plot(range(30, 91, 10), recall, marker="o", linestyle="-", label = "Recall")
plt.plot(range(30, 91, 10), f1_score, marker="o", linestyle="-", label = "F1-score")
plt.xlabel("")
plt.ylabel("")
'''
plt.legend()
'''
plt.grid()
plt.savefig("sensib.png", dpi=600, bbox_inches="tight")
plt.show()
